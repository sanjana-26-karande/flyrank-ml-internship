# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sanjana-26-karande/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I have chosen the Refresh / Content Opportunity Scoring lane. The goal of this project is to identify which content pages should be reviewed first for refresh or improvement using search and engagement data. I selected this lane because it helps prioritize content based on measurable search and engagement signals instead of guesswork, making it useful for content teams.

# %%
print("Lane selected: Refresh / Content Opportunity Scoring")
# Out:
# Lane selected: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## The Question
#
# **Decision:** Which content pages should be reviewed first for refresh?
#
# **Unit of Analysis:** One content page.
#
# **Output:** A ranked list of pages that may need refreshing.
#
# **Action:** A content editor or SEO team can use this ranking to decide which pages to refresh, improve, expand, or monitor.
#
# **Cost of a Wrong Recommendation:** A wrong recommendation may waste time reviewing pages that do not need attention or miss pages that actually require improvement. Therefore, the results are intended to support human decision-making rather than replace it.

# %%
print("Decision, action, and cost defined.")
# Out:
# Decision, action, and cost defined.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 content pages**, providing enough data for meaningful analysis. The average number of impressions over the last 90 days is **5,200.37**, while the average CTR is **0.5107**. Additionally, **16,262 pages** show a declining trend. These numbers suggest that there are many pages that may benefit from review, making the Refresh / Content Opportunity Scoring lane a practical and useful project for the next seven weeks.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average impressions (90 days):", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Number of pages: 30000
# Average impressions (90 days): 5200.37
# Average CTR: 0.5107
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project is intended to provide decision support by identifying content pages that may benefit from review based on observed search and engagement data. The results will highlight patterns and priorities, but they cannot prove that refreshing a page will improve rankings or traffic. The recommendations should be treated as evidence-based suggestions that support human decision-making rather than automatic decisions. This project does not predict Google's ranking algorithm or establish cause-and-effect relationships.

# %%
print("Section 4 completed.")
# Out:
# Section 4 completed.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
